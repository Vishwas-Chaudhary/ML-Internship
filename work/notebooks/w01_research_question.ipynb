# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishwas-Chaudhary/ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
print("""
Lane 4: CTR / Engagement Opportunity Scoring

I chose this lane because my Week-1 discovery showed that CTR varied by
content type even within position tiers. I want to investigate which
visible pages appear to under-capture clicks or engagement relative to
similar pages, so that a reviewer can prioritize pages for further review.
""")
# Out:
# Lane 4: CTR / Engagement Opportunity Scoring
#
# I chose this lane because my Week-1 discovery showed that CTR varied by
# content type even within position tiers. I want to investigate which
# visible pages appear to under-capture clicks or engagement relative to
# similar pages, so that a reviewer can prioritize pages for further review.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
print("""
Research question:
Among visible pages, which pages have lower-than-expected CTR or engagement
relative to their position tier, and which of these pages should be reviewed first?

Decision:
Which pages should a content/search team prioritize for review?

Action:
A reviewer could investigate the page's title/meta, intent match, snippet
structure, content quality, or engagement experience.

Cost of a wrong call:
Prioritizing a weak candidate wastes limited review time, while missing a
strong candidate can delay a potentially useful content improvement.
""")
# Out:
# Research question:
# Among visible pages, which pages have lower-than-expected CTR or engagement
# relative to their position tier, and which of these pages should be reviewed first?
#
# Decision:
# Which pages should a content/search team prioritize for review?
#
# Action:
# A reviewer could investigate the page's title/meta, intent match, snippet
# structure, content quality, or engagement experience.
#
# Cost of a wrong call:
# Prioritizing a weak candidate wastes limited review time, while missing a
# strong candidate can delay a potentially useful content improvement.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print("""
Quick look at the data:

The observed mean CTR varied across position tiers:
- page_1: 0.3548
- top_3: 0.3341
- striking: 0.2558
- page_3_5: 0.1424
- deep: 0.0554

I also observed that comparison articles had the lowest CTR in most
position tiers, including 0.000 in the top_3 tier.
""")
# Out:
# Quick look at the data:
#
# The observed mean CTR varied across position tiers:
# - page_1: 0.3548
# - top_3: 0.3341
# - striking: 0.2558
# - page_3_5: 0.1424
# - deep: 0.0554
#
# I also observed that comparison articles had the lowest CTR in most
# position tiers, including 0.000 in the top_3 tier.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("""
Careful words:

I can say that the data shows an observed and directional relationship
between content type, position tier, and CTR.

I can use these observations to help prioritize pages for further review.

I cannot claim that content type or position directly causes changes in CTR,
or that this analysis explains or proves Google's ranking algorithm.

These findings should be treated as decision-support rather than causal proof.
""")
# Out:
# Careful words:
#
# I can say that the data shows an observed and directional relationship
# between content type, position tier, and CTR.
#
# I can use these observations to help prioritize pages for further review.
#
# I cannot claim that content type or position directly causes changes in CTR,
# or that this analysis explains or proves Google's ranking algorithm.
#
# These findings should be treated as decision-support rather than causal proof.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
